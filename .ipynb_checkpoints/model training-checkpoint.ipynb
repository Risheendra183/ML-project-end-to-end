# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('algerian forest fires cleaned data.csv')

# %%
df
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      1      6  2012           32  71  12   0.7  57.1   2.5   8.2  0.6   2.8
# 2      1      7  2012           28  58  18   2.2  63.7   3.2   8.5  1.2   3.3
# 3      1      7  2012           29  68  19   1.0  59.9   2.5   8.6  1.1   2.9
# 4      1      8  2012           36  45  14   0.0  78.8   4.8  10.2  2.0   4.7
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 238    9      7  2012           36  43  15   1.9  82.3   9.4   9.9  3.2   9.0
# 239    9      8  2012           35  59  17   0.0  87.4  14.8  57.0  6.9  17.9
# 240    9      8  2012           39  43  12   0.0  91.7  16.5  30.9  9.6  16.4
# 241    9      9  2012           30  77  15   1.0  56.1   2.1   8.4  0.7   2.6
# 242    9      9  2012           30  80  15   0.0  83.1   7.9  34.5  3.5  10.0
#
#       FWI      Classes  region
# 0     0.5  not fire          0
# 1     0.2  not fire          0
# 2     0.5  not fire          0
# 3     0.4  not fire          0
# 4     0.9  not fire          0
# ..    ...          ...     ...
# 238   3.1      fire          1
# 239   9.9      fire          1
# 240  12.7      fire          1
# 241   0.2  not fire          1
# 242   3.7      fire          1
#
# [243 rows x 15 columns]

# %%
df.drop(['day','month','year'],axis=1,inplace=True)

# %%
df
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI   FWI  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4   0.5
# 1             32  71  12   0.7  57.1   2.5   8.2  0.6   2.8   0.2
# 2             28  58  18   2.2  63.7   3.2   8.5  1.2   3.3   0.5
# 3             29  68  19   1.0  59.9   2.5   8.6  1.1   2.9   0.4
# 4             36  45  14   0.0  78.8   4.8  10.2  2.0   4.7   0.9
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...   ...
# 238           36  43  15   1.9  82.3   9.4   9.9  3.2   9.0   3.1
# 239           35  59  17   0.0  87.4  14.8  57.0  6.9  17.9   9.9
# 240           39  43  12   0.0  91.7  16.5  30.9  9.6  16.4  12.7
# 241           30  77  15   1.0  56.1   2.1   8.4  0.7   2.6   0.2
# 242           30  80  15   0.0  83.1   7.9  34.5  3.5  10.0   3.7
#
#          Classes  region
# 0    not fire          0
# 1    not fire          0
# 2    not fire          0
# 3    not fire          0
# 4    not fire          0
# ..           ...     ...
# 238      fire          1
# 239      fire          1
# 240      fire          1
# 241  not fire          1
# 242      fire          1
#
# [243 rows x 12 columns]

# %%
df['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# not fire           2
# fire               2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
#encoding 
df['Classes']=np.where(df['Classes'].str.contains("not fire"),0,1)

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           32  71  12   0.7  57.1  2.5   8.2  0.6  2.8  0.2        0       0
# 2           28  58  18   2.2  63.7  3.2   8.5  1.2  3.3  0.5        0       0
# 3           29  68  19   1.0  59.9  2.5   8.6  1.1  2.9  0.4        0       0
# 4           36  45  14   0.0  78.8  4.8  10.2  2.0  4.7  0.9        0       0

# %%
df.tail()
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI   FWI  Classes  \
# 238           36  43  15   1.9  82.3   9.4   9.9  3.2   9.0   3.1        1
# 239           35  59  17   0.0  87.4  14.8  57.0  6.9  17.9   9.9        1
# 240           39  43  12   0.0  91.7  16.5  30.9  9.6  16.4  12.7        1
# 241           30  77  15   1.0  56.1   2.1   8.4  0.7   2.6   0.2        0
# 242           30  80  15   0.0  83.1   7.9  34.5  3.5  10.0   3.7        1
#
#      region
# 238       1
# 239       1
# 240       1
# 241       1
# 242       1

# %%
df['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
#independent and dependent features
x=df.drop('FWI',axis=1)
y=df['FWI']

# %%
x.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  Classes  region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4        0       0
# 1           32  71  12   0.7  57.1  2.5   8.2  0.6  2.8        0       0
# 2           28  58  18   2.2  63.7  3.2   8.5  1.2  3.3        0       0
# 3           29  68  19   1.0  59.9  2.5   8.6  1.1  2.9        0       0
# 4           36  45  14   0.0  78.8  4.8  10.2  2.0  4.7        0       0

# %%
y
# Out:
# 0       0.5
# 1       0.2
# 2       0.5
# 3       0.4
# 4       0.9
#        ...
# 238     3.1
# 239     9.9
# 240    12.7
# 241     0.2
# 242     3.7
# Name: FWI, Length: 243, dtype: float64

# %%
#train test split

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
x_train.shape,x_test.shape
# Out:
# ((182, 11), (61, 11))

# %%
#feature selection based om correleation

x_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.667440 -0.235083 -0.217437  0.665296  0.478533
# RH             -0.667440  1.000000  0.262210  0.193311 -0.653424 -0.439088
# Ws             -0.235083  0.262210  1.000000  0.062703 -0.165970  0.001877
# Rain           -0.217437  0.193311  0.062703  1.000000 -0.463488 -0.248948
# FFMC            0.665296 -0.653424 -0.165970 -0.463488  1.000000  0.613990
# DMC             0.478533 -0.439088  0.001877 -0.248948  0.613990  1.000000
# DC              0.368268 -0.274378  0.080067 -0.270651  0.522822  0.875166
# ISI             0.624052 -0.707227  0.000268 -0.322626  0.760906  0.723591
# BUI             0.452803 -0.390317  0.029010 -0.262021  0.600976  0.984066
# Classes         0.515321 -0.460503 -0.095345 -0.379775  0.793231  0.595427
# region         -0.057394  0.084578  0.069237  0.052956  0.026115  0.117141
#
#                    DC       ISI       BUI   Classes    region
# Temperature  0.368268  0.624052  0.452803  0.515321 -0.057394
# RH          -0.274378 -0.707227 -0.390317 -0.460503  0.084578
# Ws           0.080067  0.000268  0.029010 -0.095345  0.069237
# Rain        -0.270651 -0.322626 -0.262021 -0.379775  0.052956
# FFMC         0.522822  0.760906  0.600976  0.793231  0.026115
# DMC          0.875166  0.723591  0.984066  0.595427  0.117141
# DC           1.000000  0.552436  0.945523  0.528165  0.150702
# ISI          0.552436  1.000000  0.682546  0.738517 -0.033925
# BUI          0.945523  0.682546  1.000000  0.590466  0.131667
# Classes      0.528165  0.738517  0.590466  1.000000  0.023635
# region       0.150702 -0.033925  0.131667  0.023635  1.000000

# %%
##check for multi collinearity
plt.figure(figsize=(12,10))
corr=x_train.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
def correlation(dataset,threshold):
    col_corr=set()
    corr_matrix=dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>threshold:
                colname=corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
#threshold set by the domain expert

correlation(x_train,0.85)
# Out:
# {'BUI', 'DC'}

# %%
##drop the features when correlation is more than 0.85
x_train.drop(corr_features,axis=1,inplace=True)
x_test.drop(corr_features,axis=1,inplace=True)
x_train.shape,x_test.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 ##drop the features when correlation is more than 0.85
# ----> 2 x_train.drop(corr_features,axis=1,inplace=True)
#       3 x_test.drop(corr_features,axis=1,inplace=True)
#       4 x_train.shape,x_test.shape
#
# NameError: name 'corr_features' is not defined

# %% [markdown]
# #feature scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.fit_transform(x_test)

x_train_scaled
# Out:
# array([[ 0.20934086,  0.20378905, -0.14327741, ..., -0.02200329,
#          0.87577982, -0.98907071],
#        [-1.79592422,  1.27496904,  2.02976333, ..., -0.94772375,
#         -1.14183951,  1.01105006],
#        [ 1.35520662, -0.46569844, -0.14327741, ...,  0.78714497,
#          0.87577982,  1.01105006],
#        ...,
#        [ 2.21460594, -1.87162218, -0.50545087, ..., -0.42657741,
#          0.87577982, -0.98907071],
#        [ 0.78227374,  0.06989155, -0.50545087, ..., -0.77629403,
#         -1.14183951,  1.01105006],
#        [ 0.4958073 , -0.2648522 , -0.86762433, ...,  0.51971461,
#         -1.14183951, -0.98907071]], shape=(182, 11))

# %%
##box plots to umderstand effwct of standard scalar
plt.subplots(figsize=(15,5))
plt.subplot(1,2,1)
sns.boxplot(data=x_train)
plt.title('x_train before scaling')
plt.subplot(1,2,2)
sns.boxplot(data=x_train_scaled)
plt.title('x_train after scaling')
# Out:
# Text(0.5, 1.0, 'x_train after scaling')

# %% [markdown]
# LINEAR REGRESSION MODEL

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,r2_score

linreg=LinearRegression()
linreg.fit(x_train_scaled,y_train)

y_pred=linreg.predict(x_test_scaled)
mae=mean_absolute_error(y_test,y_pred)

score=r2_score(y_test,y_pred)

print("mean absolute error",mae)
print("r2 score",score)

plt.scatter(y_test,y_pred)
# Out:
# mean absolute error 0.9666672061678343
# r2 score 0.8732345785409352

# %% [markdown]
# #lasso regrression

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error,r2_score

lasso=Lasso()
lasso.fit(x_train_scaled,y_train)

y_pred=lasso.predict(x_test_scaled)
mae=mean_absolute_error(y_test,y_pred)

score=r2_score(y_test,y_pred)

print("mean absolute error",mae)
print("r2 score",score)

plt.scatter(y_test,y_pred)
# Out:
# mean absolute error 1.158245771589963
# r2 score 0.9112013421466267

# %%
from sklearn.linear_model import LassoCV
lassocv=LassoCV(cv=5)
lassocv.fit(x_train_scaled,y_train)
# Out:
# LassoCV(cv=5)

# %%
lassocv. alpha_
# Out:
# np.float64(0.031538649907655286)

# %%
lassocv. alphas_
# Out:
# array([7.28583719, 6.79479614, 6.33684963, 5.90976717, 5.51146864,
#        5.1400141 , 4.79359435, 4.47052214, 4.16922391, 3.88823217,
#        3.62617834, 3.38178605, 3.15386499, 2.94130505, 2.74307093,
#        2.55819713, 2.38578321, 2.2249894 , 2.07503256, 1.93518231,
#        1.8047575 , 1.68312289, 1.56968604, 1.46389445, 1.36523287,
#        1.27322074, 1.18740992, 1.10738247, 1.0327486 , 0.9631448 ,
#        0.89823206, 0.83769423, 0.78123644, 0.72858372, 0.67947961,
#        0.63368496, 0.59097672, 0.55114686, 0.51400141, 0.47935944,
#        0.44705221, 0.41692239, 0.38882322, 0.36261783, 0.33817861,
#        0.3153865 , 0.2941305 , 0.27430709, 0.25581971, 0.23857832,
#        0.22249894, 0.20750326, 0.19351823, 0.18047575, 0.16831229,
#        0.1569686 , 0.14638945, 0.13652329, 0.12732207, 0.11874099,
#        0.11073825, 0.10327486, 0.09631448, 0.08982321, 0.08376942,
#        0.07812364, 0.07285837, 0.06794796, 0.0633685 , 0.05909767,
#        0.05511469, 0.05140014, 0.04793594, 0.04470522, 0.04169224,
#        0.03888232, 0.03626178, 0.03381786, 0.03153865, 0.02941305,
#        0.02743071, 0.02558197, 0.02385783, 0.02224989, 0.02075033,
#        0.01935182, 0.01804758, 0.01683123, 0.01569686, 0.01463894,
#        0.01365233, 0.01273221, 0.0118741 , 0.01107382, 0.01032749,
#        0.00963145, 0.00898232, 0.00837694, 0.00781236, 0.00728584])

# %% [markdown]
# #RIDGE REGRESSION

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error,r2_score

ridge=Ridge()
ridge.fit(x_train_scaled,y_train)
y_pred=ridge.predict(x_test_scaled)
mae=mean_absolute_error(y_test,y_pred)

score=r2_score(y_test,y_pred)

print("mean absolute error",mae)
print("r2 score",score)

plt.scatter(y_test,y_pred)
# Out:
# mean absolute error 0.945658564862436
# r2 score 0.8782006124885546

# %%
#elsticnet regression 

from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error,r2_score

elastic= ElasticNet()
elastic.fit(x_train_scaled,y_train)

y_pred=elastic.predict(x_test_scaled)
mae=mean_absolute_error(y_test,y_pred)

score=r2_score(y_test,y_pred)

print("mean absolute error",mae)
print("r2 score",score)

plt.scatter(y_test,y_pred)
# Out:
# mean absolute error 1.6258641126760625
# r2 score 0.8960123042465581

# %%
#elsticnet cv regression 

from sklearn.linear_model import ElasticNetCV
from sklearn.metrics import mean_absolute_error,r2_score

elasticcv= ElasticNetCV(cv=5)
elasticcv.fit(x_train_scaled,y_train)

y_pred=elasticcv.predict(x_test_scaled)
mae=mean_absolute_error(y_test,y_pred)

score=r2_score(y_test,y_pred)

print("mean absolute error",mae)
print("r2 score",score)

plt.scatter(y_test,y_pred)
# Out:
# mean absolute error 0.9440410515043041
# r2 score 0.880083411429614

# %% [markdown]
# # pickling the file

# %%
scaler
# Out:
# StandardScaler()

# %%
elasticcv
# Out:
# ElasticNetCV(cv=5)

# %%
import pickle
pickle.dump(scaler,open('scaler.pkl','wb'))
pickle.dump(elasticcv,open('elasticcv.pkl','wb'))
